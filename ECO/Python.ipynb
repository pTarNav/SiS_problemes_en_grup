# %%
import numpy as np
import scipy.io.wavfile
import matplotlib.pyplot as plt
from scipy.signal import convolve
import pandas as pd
from scipy import signal
from scipy import misc
import matplotlib.pyplot as plt
from skimage import io

# %%
plt.plot(scipy.io.wavfile.read('eco1.wav')[1])

# %%
y = scipy.io.wavfile.read('eco1.wav')[1].astype(np.int64)

# %%
Ryy = convolve(y, y[::-1])
pos_max = Ryy.argmax()
plt.plot(Ryy)
print(pos_max)
# Out:
# 242574

# %%
Ryy_2 = convolve(y, y[::-1])[248578:]
pos_max = Ryy_2.argmax()
plt.plot(Ryy)
print(pos_max)
# Out:
# 5021
